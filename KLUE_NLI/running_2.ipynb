# %%
# !pip install transformers
# !pip install datasets
# !pip install wandb
# !pip install python-dotenv

# %%
# !nvidia-smi

# %%
# %cd /content/drive/Othercomputers/내 컴퓨터/KLUE_NLI

# %%
# %pwd

# %%
# !python train.py \
--run_name klue/roberta-large_rdrop_3ep \
--save_path ./checkpoints/krl_rdrop_3ep \
--model_name_or_path klue/roberta-large \
--do_train \
--do_eval \
--output_dir /content/results \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy steps \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 16 \
--per_device_eval_batch_size 32 \
--gradient_accumulation_steps 1 \
--evaluation_strategy steps \
--logging_steps 100 \
--eval_steps 250 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--use_rdrop True

# %%
# !python train.py \
--run_name Explainable_rdrop \
--save_path ./checkpoints/Explainable_rdrop \
--model_name_or_path klue/roberta-large \
--do_train \
--do_eval \
--output_dir /content/results \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy steps \
--num_train_epochs 2 \
--learning_rate 3e-5 \
--per_device_train_batch_size 16 \
--per_device_eval_batch_size 32 \
--gradient_accumulation_steps 1 \
--evaluation_strategy steps \
--logging_steps 100 \
--eval_steps 250 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--use_rdrop True \
--use_SIC

# %%
# !python inference.py \
--save_path ./checkpoints/krl_rdrop \
--output_name krl_rdrop.csv \
--do_predict \
--output_dir ./checkpoints \
--per_device_eval_batch_size 32
